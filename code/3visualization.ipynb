# %% [markdown]
# ## 3. การสร้างกราฟ

# %% [markdown]
# จากข้อมูลทั้งหมด เราพบว่าข้อมูลของ station 102 เเละ staion 256 เป็นข้อมูลที่สมบูรณ์ที่สุดที่สามารถนำมาเปรียบเทียบ

# %% [markdown]
# # Chart pollution of Station 102

# %% [markdown]
# ## Station 102 pollution(CO)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
CO_102_data = station102['CO']

plt.figure(figsize=(10, 6))

plt.plot(CO_102_data.index, CO_102_data, label='CO', color='darkgreen')
years = CO_102_data.index.year
plt.xticks(CO_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 102 CO polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Station 102 pollution(NO,NO2,NOx,O3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
NO_102_data = station102['NO']
NO2_102_data = station102['NO2']
NOx_102_data = station102['NOx']
O3_102_data = station102['O3']
fig, ax = plt.subplots(figsize=(10, 6))
ax = plt.gca()

plt.plot(O3_102_data.index, O3_102_data, label='O3', color='crimson')
plt.plot(NO_102_data.index, NO_102_data, label='NO', color='cyan')
plt.plot(NO2_102_data.index, NO2_102_data, label='NO2', color='purple')
plt.plot(NOx_102_data.index, NOx_102_data, label='NOx', color='orange')
years = NO_102_data.index.year
plt.xticks(NO_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 102 NO,NO2,NOx,O3 polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Station 102 pollution(HR,PM2.5,PM10,TMP)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station256 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
HR_256_data = station256['HR']
PM25_256_data = station256['PM2.5']
PM10_256_data = station256['PM10']
TMP_256_data = station256['TMP']
plt.figure(figsize=(10, 6))
plt.plot(HR_256_data.index, HR_256_data, label='HR', color='blue')
plt.plot(PM25_256_data.index, PM25_256_data, label='PM2.5', color='red')
plt.plot(PM10_256_data.index, PM10_256_data, label='PM10', color='green')
plt.plot(TMP_256_data.index, TMP_256_data, label='TMP', color='grey')
years = HR_256_data.index.year
plt.xticks(HR_256_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 102 HR,PM2.5,PM10,TMP polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Chart pollution of Station 256

# %% [markdown]
# ## Station 256 pollution(CO)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
CO_256_data = station256['CO']

plt.figure(figsize=(10, 6))

plt.plot(CO_256_data.index, CO_256_data, label='CO', color='darkgreen')
years = CO_256_data.index.year
plt.xticks(CO_256_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 256 CO polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Station 256 pollution(NO,NO2,NOx,O3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
NO_256_data = station256['NO']
NO2_256_data = station256['NO2']
NOx_256_data = station256['NOx']
O3_256_data = station256['O3']
fig, ax = plt.subplots(figsize=(10, 6))
ax = plt.gca()

plt.plot(O3_256_data.index, O3_256_data, label='O3', color='crimson')
plt.plot(NO_256_data.index, NO_256_data, label='NO', color='cyan')
plt.plot(NO2_256_data.index, NO2_256_data, label='NO2', color='purple')
plt.plot(NOx_256_data.index, NOx_256_data, label='NOx', color='orange')
years = NO_256_data.index.year
plt.xticks(NO_256_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 256 all polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Station 102 pollution(HR,PM2.5,PM10.TMP)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
HR_256_data = station256['HR']
PM25_256_data = station256['PM2.5']
TMP_256_data = station256['TMP']
plt.figure(figsize=(10, 6))
plt.plot(HR_256_data.index, HR_256_data, label='HR', color='blue')
plt.plot(PM25_256_data.index, PM25_256_data, label='PM2.5', color='red')
plt.plot(PM10_256_data.index, PM10_256_data, label='PM10', color='green')
plt.plot(TMP_256_data.index, TMP_256_data, label='TMP', color='grey')
years = HR_256_data.index.year
plt.xticks(HR_256_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Station 256 all polution')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Comparation of Pollution between Station 102 and Station 256

# %% [markdown]
# ## Comparation TMP

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
TMP_102_data = station102['TMP']
TMP_256_data = station256['TMP']
plt.figure(figsize=(10, 6))
plt.plot(TMP_102_data.index, TMP_102_data, label='st102', color='blue')
plt.plot(TMP_256_data.index, TMP_256_data, label='st256', color='red')
years = TMP_102_data.index.year
plt.xticks(TMP_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('TMP Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation PM2.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
PM25_102_data = station102['PM2.5']
PM25_256_data = station256['PM2.5']
plt.figure(figsize=(10, 6))
plt.plot(PM25_102_data.index, PM25_102_data, label='st102', color='blue')
plt.plot(PM25_256_data.index, PM25_256_data, label='st256', color='red')
years = PM25_102_data.index.year
plt.xticks(PM25_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('PM25 Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation PM10

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
PM10_102_data = station102['PM10']
PM10_256_data = station256['PM10']
plt.figure(figsize=(10, 6))
plt.plot(PM10_102_data.index, PM10_102_data, label='st102', color='blue')
plt.plot(PM10_256_data.index, PM10_256_data, label='st256', color='red')
years = PM10_102_data.index.year
plt.xticks(PM10_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('PM10 Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation CO

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
CO_102_data = station102['CO']
CO_256_data = station256['CO']
plt.figure(figsize=(10, 6))
plt.plot(CO_102_data.index, CO_102_data, label='st102', color='blue')
plt.plot(CO_256_data.index, CO_256_data, label='st256', color='red')
years = CO_102_data.index.year
plt.xticks(CO_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('CO Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation O3

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
O3_102_data = station102['O3']
O3_256_data = station256['O3']
plt.figure(figsize=(10, 6))
plt.plot(O3_102_data.index, O3_102_data, label='st102', color='blue')
plt.plot(O3_256_data.index, O3_256_data, label='st256', color='red')
years = O3_102_data.index.year
plt.xticks(O3_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('O3 Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation HR

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
HR_102_data = station102['HR']
HR_256_data = station256['HR']
plt.figure(figsize=(10, 6))
plt.plot(HR_102_data.index, HR_102_data, label='st102', color='blue')
plt.plot(HR_256_data.index, HR_256_data, label='st256', color='red')
years = HR_102_data.index.year
plt.xticks(HR_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('HR Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation  NO

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
NO_102_data = station102['NO']
NO_256_data = station256['NO']
plt.figure(figsize=(10, 6))
plt.plot(NO_102_data.index, NO_102_data, label='st102', color='blue')
plt.plot(NO_256_data.index, NO_256_data, label='st256', color='red')
years = NO_102_data.index.year
plt.xticks(NO_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('NO Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation NO2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
NO2_102_data = station102['NO2']
NO2_256_data = station256['NO2']
plt.figure(figsize=(10, 6))
plt.plot(NO2_102_data.index, NO2_102_data, label='st102', color='blue')
plt.plot(NO2_256_data.index, NO2_256_data, label='st256', color='red')
years = NO2_102_data.index.year
plt.xticks(NO2_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('NO2 Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Comparation NOx

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator

data = pd.read_csv('../data/data_hourly_clean_daily.csv')
data["datetime"] = pd.to_datetime(data["datetime"])

station102 = data.loc[data["station_id"] == 102].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
station256 = data.loc[data["station_id"] == 256].groupby([pd.Grouper(freq="Y", key="datetime")]).mean()
NOx_102_data = station102['NOx']
NOx_256_data = station256['NOx']
plt.figure(figsize=(10, 6))
plt.plot(NOx_102_data.index, NOx_102_data, label='st102', color='blue')
plt.plot(NOx_256_data.index, NOx_256_data, label='st256', color='red')
years = NOx_102_data.index.year
plt.xticks(NOx_102_data.index, years, rotation=45)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('NOx Levels for Station 102 and Station 256')
plt.legend()
plt.grid(True)
plt.ylim(ymin=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
